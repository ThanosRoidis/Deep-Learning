# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import glob
import pickle as picklerick
from tensorboard.backend.event_processing import event_accumulator
# %matplotlib inline

# %%
files = glob.glob( './Assignment 2/part1/summaries/**/*')

eas = []
for filepath in sorted(files):
    ea = event_accumulator.EventAccumulator(filepath,
        size_guidance={ # see below regarding this argument
        event_accumulator.COMPRESSED_HISTOGRAMS: 0,
        event_accumulator.IMAGES: 0,
        event_accumulator.AUDIO: 0,
        event_accumulator.SCALARS: 0,
        event_accumulator.HISTOGRAMS: 0,
       })
    ea.Reload()
    eas.append(ea)

# %%
ea.Scalars('loss')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-b7cfa68e5917> in <module>()
# ----> 1 ea.Scalars('loss')
#
# ~/anaconda3/lib/python3.6/site-packages/tensorboard/backend/event_processing/event_accumulator.py in Scalars(self, tag)
#     446       An array of `ScalarEvent`s.
#     447     """
# --> 448     return self.scalars.Items(tag)
#     449
#     450   def Graph(self):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorboard/backend/event_processing/reservoir.py in Items(self, key)
#     108     with self._mutex:
#     109       if key not in self._buckets:
# --> 110         raise KeyError('Key %s was not found in Reservoir' % key)
#     111       bucket = self._buckets[key]
#     112     return bucket.Items()
#
# KeyError: 'Key loss was not found in Reservoir'

# %%
import copy
# tags = ['test_accuracy', 'training_accuracy','training_loss']
tags = ['training_accuracy','training_loss']
batches = 1501
for tag in tags:
    frames = []

    for ea in eas:
        frames.append(pd.DataFrame(ea.Scalars(tag)))

    fig = plt.figure()
    ax = frames[0].plot(x='step' , y='value')
    frames = frames[1:]
    for frame in frames:
        ax = frame.plot(x='step' , y='value', ax=ax)
#     plt.legend(['ConvNet base', 'with dropout', 'with batch normalization', 'with data augmentation', 'adagrad 1e-4', 'adagrad 1e-3', 'adadelta 1e-4', 'adadelta 1e-3', 'rmsprop 1e-4', 'rmsprop 1e-3'])
    plt.legend(['length 30', 'length 60', 'with batch normalization', 'with data augmentation', 'adagrad 1e-4', 'adagrad 1e-3', 'adadelta 1e-4', 'adadelta 1e-3', 'rmsprop 1e-4', 'rmsprop 1e-3'])
    
    s = tag.replace('_', ' ')
    plt.xlabel('iterations')
    plt.ylabel(s)
    title = copy.copy(s)
    title = title[0].upper() + title[1:]
    plt.title(title)
#     ax.set_xlim([0, batches+100])
#     if 'test' in tag:
#         plt.xticks(np.arange(100, batches, 200))
    plt.savefig('./plots/convnet/improvements/' + tag+'.pdf')
    plt.show()

# %%
import numpy as np

with open("train_losses.dat", "rb") as f:
    train_losses = picklerick.load(f)

with open("train_accs.dat", "rb") as f:
    train_accs = picklerick.load(f)

with open("test_accs.dat", "rb") as f:
    test_accs = picklerick.load(f)

x = np.arange(100, 1505, 100)
plt.figure()
plt.plot(train_accs)
plt.xlabel('steps')
plt.ylabel('accuracy')
plt.title('Training accuracy')
plt.savefig('training_acc_mlp_numpy.pdf')
plt.show()

plt.figure()
ax = plt.plot(x, test_accs)
plt.xlabel('steps')
plt.ylabel('accuracy')
plt.title('Test accuracy')
plt.savefig('test_acc_mlp_numpy.pdf')
plt.xticks(np.arange(100, 1505, 200))
plt.show()

plt.figure()
plt.plot(train_losses)
plt.xlabel('steps')
plt.ylabel('loss')
plt.title('Training loss')
plt.savefig('training_loss_mlp_numpy.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-0e3370164995> in <module>()
#      20
#      21 plt.figure()
# ---> 22 ax = plt.plot(x, test_accs)
#      23 plt.xlabel('steps')
#      24 plt.ylabel('accuracy')
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# /home/nedko/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (15,) and (17,)

# %%
confusion_m = np.array([[605,  46,  72,  17,  36,  17,  31,  20, 111,  45],
 [ 48, 641,  13,  33,   6,  12,  23,  18,  67, 139],
 [ 72,  14, 402, 107, 118,  96, 108,  50,  17,  16],
 [ 20,  19,  85, 377,  64, 228, 106,  48,  21,  32],
 [ 31,  11, 139,  69, 457,  71, 103,  69,  32,  18],
 [ 14,   7,  75, 206,  67, 471,  58,  63,  15,  24],
 [ 13,  16,  67,  97, 91,  50, 617,  15,  17,  17],
 [ 31,  13,  48,  66, 78,  98,  18, 591,   7,  50],
 [106,  63,  17,  30,  27,  15,  12,   8, 679,  43],
 [ 42, 189,  20,  34,  24,  19,  27,  40,  70, 535]])

import numpy as np
import matplotlib.pyplot as plt
plt.imshow(confusion_m);
plt.colorbar()
plt.show()
