# %%
import argparse
import numpy as np
import os 

import time
import sys
import pickle
import csv

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Tensorflow plots

# %%
def plot_csv(filename, x_metric):
    
    
    x = []
    y = []
    
    with open(filename, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',')
        c = 0
        for row in spamreader:
            if c == 0:
                c+=1
                continue
            
            vals = [float(i) for i in row]
            if x_metric == 'wall time':
                x.append(vals[0])
                
            if x_metric == 'step':
                x.append(vals[1])
                
            y.append(vals[2])
    
    if x_metric == 'wall time':
        start_time = x[0]
        x = [i - start_time for i in x]
        
    plt.plot(x,y)
    
    print('max:', np.max(y), x[np.argmax(y)])
    print('last:', y[-1])
                
        
        
        
        
#     for i in range(len(folder_names)):
        
#         with open (folder_names[i] + 'results.pkl', 'rb') as fp:
#             model_results = pickle.load(fp)
            
#             x_range, loss, acc = zip(*model_results)
            
#             x_ranges.append(x_range)
#             losses.append(loss)
#             accuracies.append(acc)
            
#     for i in range(len(x_ranges)):
#         plt.plot(x_ranges[i], losses[i])
        
#     plt.xlabel('Training step')
#     plt.ylabel('Loss')
#     plt.legend(legend_names)
#     plt.show()
    
#     for i in range(len(x_ranges)):
#         plt.plot(x_ranges[i], accuracies[i]) 
#     plt.xlabel('Training step')
#     plt.ylabel('Accuracy')
#     plt.legend(legend_names)
#     plt.show()

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_500-tag-accuracy_acc.csv', 'step') 

plt.xlabel('Training step')
plt.ylabel('Test accuracy')
plt.legend(['500 hidden units'])

plt.ylim(0.2,0.60)
plt.show()
# Out:
# ('max:', 0.56499987840652466, 10000.0)
# ('last:', 0.5649998784065247)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_0-tag-accuracy_acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_100-tag-accuracy_acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_300-tag-accuracy_acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_500-tag-accuracy_acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_500-300-tag-accuracy_acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Test accuracy')
plt.legend(['logistic regression',
            '100 hidden units',
            '300 hidden units',
            '500 hidden units',
            '500-300 hidden units'])

plt.ylim(0.2,0.60)
plt.show()
# Out:
# ('max:', 0.41099989414215088, 2000.0)
# ('last:', 0.4041999280452728)
# ('max:', 0.52239990234375, 8000.0)
# ('last:', 0.5202999114990234)
# ('max:', 0.55569988489151001, 8300.0)
# ('last:', 0.5535998940467834)
# ('max:', 0.56499987840652466, 10000.0)
# ('last:', 0.5649998784065247)
# ('max:', 0.56379985809326172, 9300.0)
# ('last:', 0.5595998764038086)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_0-tag-xent_L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_100-tag-xent_L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_300-tag-xent_L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_500-tag-xent_L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/layers experiments/run_mlp_tf_500-300-tag-xent_L.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Test loss')
plt.legend(['logistic regression',
            '100 hidden units',
            '300 hidden units',
            '500 hidden units',
            '500-300 hidden units'])
plt.show()

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-no_reg-tag-L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-no_reg_train-tag-L.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Test',
            'Train'])


plt.ylim(0,2.5)
plt.show()


plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-no_reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-no_reg_train-tag-acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Test',
            'Train'])


plt.ylim(0.2,1)
plt.show()
# Out:
# ('max:', 2.2671651840209961, 10000.0)
# ('last:', 2.267165184020996)
# ('max:', 2.3344545364379883, 0.0)
# ('last:', 0.25005263090133667)
# ('max:', 0.54009991884231567, 2800.0)
# ('last:', 0.5240998864173889)
# ('max:', 0.92525011301040649, 9900.0)
# ('last:', 0.9252501130104065)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-reg-tag-L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-reg_train-tag-L.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Test',
            'Train'])
plt.ylim(0,2.5)
plt.show()


plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-reg_train-tag-acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Test',
            'Train'])


plt.ylim(0.2,1)
plt.show()
# Out:
# ('max:', 2.2586753368377686, 0.0)
# ('last:', 1.5960748195648193)
# ('max:', 2.4255416393280029, 0.0)
# ('last:', 0.8934309482574463)
# ('max:', 0.54509985446929932, 5600.0)
# ('last:', 0.5326998829841614)
# ('max:', 0.75410002470016479, 9600.0)
# ('last:', 0.7445499897003174)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-no_reg-tag-L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-no_reg_train-tag-L.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Test',
            'Train'])
plt.ylim(0,2.5)
plt.show()


plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-no_reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-no_reg_train-tag-acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Test',
            'Train'])


plt.ylim(0.2,1)
plt.show()
# Out:
# ('max:', 2.1795897483825684, 0.0)
# ('last:', 1.3071469068527222)
# ('max:', 2.4238693714141846, 0.0)
# ('last:', 1.0725951194763184)
# ('max:', 0.55849993228912354, 8300.0)
# ('last:', 0.5514999032020569)
# ('max:', 0.6244499683380127, 9600.0)
# ('last:', 0.6182500123977661)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-reg-tag-L.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-reg_train-tag-L.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Test',
            'Train'])

plt.ylim(0,2.5)
plt.show()


plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-reg_train-tag-acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Test',
            'Train'])


plt.ylim(0.2,1)
plt.show()
# Out:
# ('max:', 2.2398607730865479, 0.0)
# ('last:', 1.4108774662017822)
# ('max:', 2.4416394233703613, 0.0)
# ('last:', 1.400791049003601)
# ('max:', 0.53839987516403198, 9700.0)
# ('last:', 0.534899890422821)
# ('max:', 0.53819996118545532, 5600.0)
# ('last:', 0.5360499620437622)

# %%
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-no_reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_no_dropout-reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-no_reg-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/mlp_tf/regularization-dropout experiments/run_mlp_tf_dropout-reg-tag-acc.csv', 'step')

plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['No dropout/regularization',
            'regularization',
            'dropout',
            'dropout + regularization'])

plt.show()

# %%
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN2-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_DA-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN+DA-tag-acc.csv', 'step')


plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Baseline',
            'Batch normalization',
            'Data augmentation',
            'Batch normalization + Data augmentation'])

plt.show()
# Out:
# ('max:', 0.77540004253387451, 10000.0)
# ('last:', 0.7598000168800354)
# ('max:', 0.79860001802444458, 14500.0)
# ('last:', 0.7883999943733215)
# ('max:', 0.75500005483627319, 15000.0)
# ('last:', 0.7550000548362732)
# ('max:', 0.81660002470016479, 13500.0)
# ('last:', 0.8113000392913818)

# %%
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-acc.csv', 'step')
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN2-tag-acc.csv', 'step')


plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Baseline',
            'Batch normalization'])

plt.show()

plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-L.csv', 'step')
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN2-tag-L.csv', 'step')


plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Baseline',
            'Batch normalization'])


plt.show()
# Out:
# ('max:', 0.77540004253387451, 10000.0)
# ('last:', 0.7598000168800354)
# ('max:', 0.79860001802444458, 14500.0)
# ('last:', 0.7883999943733215)
# ('max:', 2.2968964576721191, 0.0)
# ('last:', 1.008063554763794)
# ('max:', 3.0309569835662842, 500.0)
# ('last:', 0.9494215846061707)

# %%
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-acc.csv', 'step') 
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_DA-tag-acc.csv', 'step') 


plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Baseline', 
            'Data augmentation'])

plt.show()

plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-L.csv', 'step') 
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_DA-tag-L.csv', 'step') 


plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Baseline', 
            'Data augmentation'])


plt.show()
# Out:
# ('max:', 0.77540004253387451, 10000.0)
# ('last:', 0.7598000168800354)
# ('max:', 0.75500005483627319, 15000.0)
# ('last:', 0.7550000548362732)
# ('max:', 2.2968964576721191, 0.0)
# ('last:', 1.008063554763794)
# ('max:', 2.3052804470062256, 0.0)
# ('last:', 0.7357566356658936)

# %%
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-acc.csv', 'step') 
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN+DA-tag-acc.csv', 'step')


plt.xlabel('Training step')
plt.ylabel('Accuracy')
plt.legend(['Baseline',
            'Batch normalization + Data augmentation'])

plt.show()

plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_Default-tag-L.csv', 'step') 
plot_csv('/home/thanos/Desktop/convnet_tf/run_convnet_tf_BN+DA-tag-L.csv', 'step')


plt.xlabel('Training step')
plt.ylabel('Loss')
plt.legend(['Baseline',
            'Batch normalization + Data augmentation'])

plt.show()
# Out:
# ('max:', 0.77540004253387451, 10000.0)
# ('last:', 0.7598000168800354)
# ('max:', 0.81660002470016479, 13500.0)
# ('last:', 0.8113000392913818)
# ('max:', 2.2968964576721191, 0.0)
# ('last:', 1.008063554763794)
# ('max:', 2.3028109073638916, 0.0)
# ('last:', 0.5638260245323181)

# %% [markdown]
# # Images

# %%
import PIL
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
img_folder = "/media/thanos/DATA/convnet_res/data_augmentation_examples/"

imgs = [img_folder + f for f in listdir(img_folder) if isfile(join(img_folder, f))]


default_img_names = imgs[1::2]
aug_img_names = imgs[0::2]

# %%
default_imgs = [ PIL.Image.open(i) for i in default_img_names ]
aug_imgs = [ PIL.Image.open(i) for i in aug_img_names ]

comb_default = np.hstack( (np.asarray( i ) for i in default_imgs ) )
comb_aug = np.hstack( (np.asarray( i ) for i in aug_imgs ) )

comb_all = np.vstack((comb_default, comb_aug))

# # save that beautiful picture
imgs_comb = PIL.Image.fromarray( comb_all)
imgs_comb.save( 'augmentation_examples.png' )    

# # for a vertical stacking it is simple: use vstack
# imgs_comb = np.vstack( (np.asarray( i.resize(min_shape) ) for i in imgs ) )
# imgs_comb = PIL.Image.fromarray( imgs_comb)
# imgs_comb.save( 'Trifecta_vertical.jpg' )
